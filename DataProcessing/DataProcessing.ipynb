# %%
import openpyxl
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import colors

# %%
# openpyxl可以针对xls和xlsx，老版的import xlrd只能导入xls

wb = openpyxl.load_workbook(filename='../Single_reciprocating/0125-0125-2p_9%_2.8L4H2.8U4C_Openloop_dispswap.xlsx')
# !!!Remeber to save as a 'Excel Workbook' with xlsx, otherwise it canno be opened
a = wb.get_sheet_names()  
#tl = wb.get_sheet_by_name('Delta_T')  
#force = wb.get_sheet_by_name('FvsDisp')
# Out:
# <ipython-input-67-7d8539cab638>:5: DeprecationWarning: Call to deprecated function get_sheet_names (Use wb.sheetnames).
#   a = wb.get_sheet_names()

# %% [markdown]
# # Temperature change

# %%
TC = pd.read_excel('../Single_reciprocating/0130-3.5p_12%_5.5L4H5.4U4C_Openloop.xlsx', sheet_name = '0130-3.5p_12%_5.5L4H5.4U4C_Open')
TC.head(8)
# Out:
#        time        0_TC01        1_TC02        2_TC03        3_TC04  \
# 0       NaN            ∞C            ∞C            ∞C            ∞C
# 1  0.000000 -56214.929455 -56231.793141 -55998.291417 -56270.435011
# 2  0.008280 -56213.474027 -56230.337276 -55996.880209 -56269.016948
# 3  0.016544 -56213.474027 -56230.337276 -55996.880209 -56269.016948
# 4  0.024928 -56213.474027 -56230.337276 -55996.880209 -56269.016948
# 5  0.033236 -56213.474027 -56230.337276 -55996.880209 -56269.016948
# 6  0.041669 -56213.687199 -56230.550512 -55997.074366 -56269.212048
# 7  0.050076 -56213.687199 -56230.550512 -55997.074366 -56269.212048
#
#          4_TC05        5_TC06        6_TC07     7_TC08     8_TC09  ...  \
# 0            ∞C            ∞C            ∞C         ∞C         ∞C  ...
# 1  -56249.11239 -56221.564107 -56214.824421  24.287584  24.127258  ...
# 2 -56247.694865 -56220.108506 -56213.368995  24.286672  24.128188  ...
# 3 -56247.694865 -56220.108506 -56213.368995  24.286672  24.128188  ...
# 4 -56247.694865 -56220.108506 -56213.368995  24.286672  24.128188  ...
# 5 -56247.694865 -56220.108506 -56213.368995  24.286672  24.128188  ...
# 6 -56247.889891 -56220.321703 -56213.582166  24.282295  24.118284  ...
# 7 -56247.889891 -56220.321703 -56213.582166  24.282295  24.118284  ...
#
#   31_AI15_NC     32_LCA          33_LCB  34_LCC_367756 35_LCD_296498  \
# 0                   lbs             lbs            lbs           lbs
# 1          0  50.422014 -1163566.241766 -1395592.92276 -41794.824668
# 2          0  48.043357 -1163566.241766 -1395592.92276 -41798.375482
# 3          0  48.043357 -1163566.241766 -1395592.92276 -41798.375482
# 4          0  45.494796 -1163566.241766 -1395592.92276  -41789.58299
# 5          0  45.494796 -1163566.241766 -1395592.92276  -41789.58299
# 6          0  52.630767 -1163566.241766 -1395592.92276 -41796.684618
# 7          0  52.630767 -1163566.241766 -1395592.92276 -41796.684618
#
#   Offset Height A Offset Height B Displacement A Displacement B Unnamed: 41
# 0              in              in             in             in         NaN
# 1         0.18881        0.212435       0.043235       0.024752         0.0
# 2         0.18881        0.212435       0.043238       0.024758         0.0
# 3         0.18881        0.212435       0.043238       0.024758         0.0
# 4         0.18881        0.212435        0.04324       0.024755         0.0
# 5         0.18881        0.212435        0.04324       0.024755         0.0
# 6         0.18881        0.212435       0.043245       0.024749         0.0
# 7         0.18881        0.212435       0.043245       0.024749         0.0
#
# [8 rows x 42 columns]

# %%
fig,ax = plt.subplots(figsize=(12,8))

tube4 = ax.plot(TC['time'][3:], (TC['8_TC09'][3:])-(TC['7_TC08'][3:])+0.3, color = 'darkorange')

plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
ax.set_xlabel('Time [min]', fontsize = 18)
ax.set_ylabel('Delta_T [K]', fontsize = 18)
ax.set_title('Average strain = 3.5% \n HTP = 12%', fontsize = 20)
ax.set_xlim(0,30)
#ax.legend(fontsize = 18)
ax.grid()

# %% [markdown]
# ## Temperature change of individual tube

# %%
fig,ax = plt.subplots(figsize=(12,8))

tube4 = ax.plot(TC['time'][3:]-2, (TC['0_TC01'][3:]-2)-(TC['1_TC02'][3:]-2), color = 'darkorange', label = 'tube4')
tube3 = ax.plot(TC['time'][3:]-2, (TC['2_TC03'][3:]-2)-(TC['3_TC04'][3:]-2), color = 'thistle', label = 'tube3')
tube2 = ax.plot(TC['time'][3:]-2, (TC['4_TC05'][3:]-2)-(TC['5_TC06'][3:]-2), color = 'yellowgreen', label = 'tube2')
tube1 = ax.plot(TC['time'][3:]-2, (TC['6_TC07'][3:]-2)-(TC['7_TC08'][3:]-2), color = '#6495ED', label = 'tube1')

plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
ax.set_xlabel('Time [min]', fontsize = 18)
ax.set_ylabel('Delta_T [K]', fontsize = 18)
ax.set_title('4 bundle open loop \n Average strain = 3.0% \n HTP=16%', fontsize = 20)
ax.set_xlim(0,40)
ax.legend(fontsize = 18)
ax.grid()

# %% [markdown]
# ## Temperature lift

# %%
fig,ax = plt.subplots(figsize=(8,10))

th = ax.plot(TC['time'][3:], TC['8_TC09'][3:], color = 'darkorange', label = 'T$_h$')
tc = ax.plot(TC['time'][3:], TC['7_TC08'][3:], color = '#6495ED', label = 'T$_c$')
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
ax.set_xlabel('Time [min]', fontsize = 18)
ax.set_ylabel('Temperature [K]', fontsize = 18)
# ax.text(0, 5, 'Parabola $Y = x^2$', fontsize = 22)
ax.set_title('Temperature lift \n Average strain = 3.5% \n HTP=12%', fontsize = 20)
ax.set_xlim(0,30)
#ax.set_ylim(-2,10)
ax.legend(fontsize = 18)
ax.grid()

# %% [markdown]
# # Force distribution

# %%
fig,ax = plt.subplots(figsize=(15,9))

#lca = ax.plot(TC['time'][1:], TC['32_LCA'][1:], color = 'darkorange', label = 'LC_1', linewidth = 2)
#lcb = ax.plot(TC['time'][1:], TC['33_LCB'][1:]+6000, color = 'darkorange', linestyle='dashed', 
#              linewidth = 2, label = 'LC_2')
#lcc = ax.plot(TC['time'][3:], TC['34_LCC_367756'][3:]+12500, color = '#6495ED', label = 'LC_A', linewidth = 2,)
lcd = ax.plot(TC['time'][3:], TC['35_LCD_296498'][3:]+44000, color = 'darkorange', linestyle='dashed', 
              linewidth = 2, label = 'LC_B')
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
ax.set_xlabel('Time [min]', fontsize = 18)
ax.set_ylabel('Force [lbs]', fontsize = 18)
ax.set_title('Force \n Average strain = 3.5% \n HTP = 12%', fontsize = 20)
ax.set_xlim(0,30)
#ax.set_ylim(-1000,30000)
ax.legend(loc = 'upper left' ,fontsize = 14)
ax.grid()

# %%
fig,ax = plt.subplots(figsize=(15,9))

lca = ax.plot(Force['time'][1:], Force['32_LCA'][1:], color = 'darkorange', label = 'LC_1', linewidth = 2)
lcb = ax.plot(Force['time'][1:], Force['33_LCB'][1:]+6000, color = 'darkorange', linestyle='dashed', 
              linewidth = 2, label = 'LC_2')
lcc = ax.plot(Force['time'][1:], Force['34_LCC_367756'][1:], color = '#6495ED', label = 'LC_3', linewidth = 2,)
lcd = ax.plot(Force['time'][1:], Force['35_LCD_296498'][1:], color = '#6495ED', linestyle='dashed', 
              linewidth = 2, label = 'LC_4')
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
ax.set_xlabel('Time [min]', fontsize = 18)
ax.set_ylabel('Force [lbs]', fontsize = 18)
ax.set_title('Force_1% Strain', fontsize = 20)
ax.set_xlim(40,41)
ax.legend(loc = 'upper left', fontsize = 14)
ax.grid()

# %% [markdown]
# # Cylinder displacement

# %%
fig,ax = plt.subplots(figsize=(15,9))

#A = ax.plot(TC['time'][1:], TC['Displacement A'][1:], color = '#6495ED', label = 'Displacement A')
A = ax.plot(TC['time'][1:], TC['18_AI2_Displ_Transd_CylA'][1:]+0.08, color = '#6495ED', label = 'Displacement A')
B = ax.plot(TC['time'][1:], TC['17_AI1_Displ_Transd_CylB'][1:]+0.13, color = 'darkorange', label = 'Displacement B')
#B = ax.plot(TC['time'][1:], TC['Displacement B'][1:], color = 'darkorange', label = 'Displacement B')
#17_AI1_Displ_Transd_CylB
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
ax.set_xlabel('Time [min]', fontsize = 18)
ax.set_ylabel('Displacement [inch]', fontsize = 18)
ax.set_title('Displacement \n Average strain = 3% \n HTP = 12%', fontsize = 20)
ax.set_xlim(20,21)
#ax.set_ylim(0,0.3)
ax.legend(loc='upper left', fontsize = 14)
ax.grid()
#darkorange
#6495ED

# %% [markdown]
# # Average TL

# %%
Average = np.average(TC['8_TC09'][4883:5041])- np.average(TC['7_TC08'][4883:5041])
print(f"The average temperature of last five cycles: {Average}")
# Out:
# The average temperature of last five cycles: 10.698059873417733
